# %% [markdown]
# <a href="https://colab.research.google.com/github/fateme-alk/google-colab-virtual-environment-dependencies/blob/main/conda_with_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# python --version
# which python
#
# # if you want to chech conda was installed on your workspace, uncomment below commands
# # conda --version
# # which conda
# Out:
# Python 3.12.12
# /usr/local/bin/python

# %%
# %%bash
# pwd
# ls -al
# Out:
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Oct 16 13:41 .
# drwxr-xr-x 1 root root 4096 Oct 19 12:45 ..
# drwxr-xr-x 4 root root 4096 Oct 16 13:41 .config
# drwxr-xr-x 1 root root 4096 Oct 16 13:41 sample_data

# %%
# %%bash
# wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Out:
# --2025-10-19 12:53:29--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
#      0K .......... .......... .......... .......... ..........  0%  965K 86s
#     50K .......... .......... .......... .......... ..........  0% 6.78M 49s
#    100K .......... .......... .......... .......... ..........  0% 1.82M 47s
#    150K .......... .......... .......... .......... ..........  0% 74.2M 36s
#    200K .......... .......... .......... .......... ..........  0%  187M 29s
#    250K .......... .......... .......... .......... ..........  0% 1.80M 31s
#    300K .......... .......... .......... .......... ..........  0%  128M 27s
# ...

# %%
# %%bash
# ls -al
# Out:
# total 83080
# drwxr-xr-x 1 root root     4096 Oct 19 12:53 .
# drwxr-xr-x 1 root root     4096 Oct 19 12:45 ..
# drwxr-xr-x 4 root root     4096 Oct 16 13:41 .config
# -rw-r--r-- 1 root root 85055499 Feb 13  2025 Miniconda3-py37_4.8.2-Linux-x86_64.sh
# drwxr-xr-x 1 root root     4096 Oct 16 13:41 sample_data

# %%
# %%bash
# echo $PYTHONPATH
# Out:
# /env/python

# %%
import os
os.environ.pop("PYTHONPATH", None)
print("PYTHONPATH is now:", os.environ.get("PYTHONPATH"))
# Out:
# PYTHONPATH is now: None

# %%
# %%bash
# echo $PYTHONPATH

# %%
# %%bash
# ls -al /usr/local/bin
# Out:
# total 93776
# drwxr-xr-x 1 1000 1000     4096 Oct 16 13:57 .
# drwxr-xr-x 1 root root     4096 Oct 16 13:57 ..
# -rwxr-xr-x 1 root root      298 Oct 16 13:48 absolufy-imports
# -rwxr-xr-x 1 root root      316 Oct 16 13:48 accelerate
# -rwxr-xr-x 1 root root      308 Oct 16 13:48 accelerate-config
# -rwxr-xr-x 1 root root      310 Oct 16 13:48 accelerate-estimate-memory
# -rwxr-xr-x 1 root root      308 Oct 16 13:48 accelerate-launch
# -rwxr-xr-x 1 root root      307 Oct 16 13:48 accelerate-merge-weights
# -rwxr-xr-x 1 root root      296 Oct 16 13:48 adk
# -rwxr-xr-x 1 root root      296 Oct 16 13:48 alembic
# -rwxr-xr-x 1 root root     1089 Oct 16 13:43 beeline
# -rwxr-xr-x 1 root root     1064 Oct 16 13:43 beeline.cmd
# -rwxr-xr-x 1 root root      296 Oct 16 13:48 bokeh
# -rwxr-xr-x 1 root root      291 Oct 16 13:48 ccmake
# -rwxr-xr-x 1 root root      304 Oct 16 13:48 chardetect
# -rwxr-xr-x 1 root root      289 Oct 16 13:48 cmake
# ...

# %%
# %%bash
# chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
# bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
# ...

# %%
# %%bash
# ls -al /usr/local/bin
# Out:
# total 111408
# drwxr-xr-x 1 1000 1000     4096 Oct 19 12:53 .
# drwxr-xr-x 1 root root     4096 Oct 19 12:53 ..
# lrwxrwxrwx 1 root root        8 Oct 19 12:53 2to3 -> 2to3-3.7
# -rwxrwxr-x 1 root root      101 Oct 19 12:53 2to3-3.7
# -rwxr-xr-x 1 root root      298 Oct 16 13:48 absolufy-imports
# -rwxr-xr-x 1 root root      316 Oct 16 13:48 accelerate
# -rwxr-xr-x 1 root root      308 Oct 16 13:48 accelerate-config
# -rwxr-xr-x 1 root root      310 Oct 16 13:48 accelerate-estimate-memory
# -rwxr-xr-x 1 root root      308 Oct 16 13:48 accelerate-launch
# -rwxr-xr-x 1 root root      307 Oct 16 13:48 accelerate-merge-weights
# -rwxrwxr-x 1 root root      184 Oct 19 12:53 activate
# -rwxr-xr-x 1 root root      296 Oct 16 13:48 adk
# -rwxr-xr-x 1 root root      296 Oct 16 13:48 alembic
# -rwxr-xr-x 1 root root     1089 Oct 16 13:43 beeline
# -rwxr-xr-x 1 root root     1064 Oct 16 13:43 beeline.cmd
# -rwxr-xr-x 1 root root      296 Oct 16 13:48 bokeh
# ...

# %%
# %%bash
# python --version
# which python
#
# conda --version
# which conda
# Out:
# Python 3.7.6
# /usr/local/bin/python
# conda 4.8.2
# /usr/local/bin/conda

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.7/site-packages"))

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/usr/local/lib/python3.7/site-packages']

# %%
# !ls -al /usr/local/envs
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Oct 19 12:53 .
# drwxr-xr-x 1 root root 4096 Oct 19 12:53 ..

# %%
# !conda init
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.7/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# modified      /root/.bashrc
#
# ==> For changes to take effect, close and re-open your current shell. <==

# %%
# !conda create --name test
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/test
#
#
#
# Proceed ([y]/n)? y
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate test
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !ls -al /usr/local/envs
# Out:
# total 16
# drwxr-xr-x 3 root root 4096 Oct 19 12:54 .
# drwxr-xr-x 1 root root 4096 Oct 19 12:53 ..
# -rw-r--r-- 1 root root    0 Oct 19 12:54 .conda_envs_dir_test
# drwxr-xr-x 3 root root 4096 Oct 19 12:54 test

# %%
# %%bash
# eval "$(conda shell.bash hook)"
# conda activate test
# conda info --envs
# Out:
# # conda environments:
# #
# base                     /usr/local
# test                  *  /usr/local/envs/test

# %%
# %%bash
# conda info --envs
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# test                     /usr/local/envs/test

# %%
# %%bash
# conda list numpy
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel

# %%
# %%bash
# conda install conda-forge::numpy
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda-forge::numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.9.9   |       h06a4308_0         127 KB
#     certifi-2020.6.20          |     pyhd3eb1b0_3         155 KB
#     libblas-3.9.0              |       8_openblas          11 KB  conda-forge
#     libcblas-3.9.0             |       8_openblas          11 KB  conda-forge
#     libgfortran-ng-7.5.0       |      ha8ba4b0_17          22 KB
#     libgfortran4-7.5.0         |      ha8ba4b0_17         995 KB
#     liblapack-3.9.0            |       8_openblas          11 KB  conda-forge
#     libopenblas-0.3.12         |pthreads_hb3c22a3_1         8.2 MB  conda-forge
#     numpy-1.15.4               |py37h8b7e671_1002         4.2 MB  conda-forge
# ...

# %%
# !conda list numpy
# Out:
# # packages in environment at /usr/local:
# #
# # Name                    Version                   Build  Channel
# numpy                     1.15.4          py37h8b7e671_1002    conda-forge

# %%
# %%bash
# eval "$(conda shell.bash hook)"
# conda activate test
# conda install -y conda-forge::numpy
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/test
#
#   added / updated specs:
#     - conda-forge::numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     expat-2.7.1                |       h6a678d5_0         182 KB
#     ld_impl_linux-64-2.44      |       h153f514_2         672 KB
#     libblas-3.9.0              |37_h4a7cf45_openblas          17 KB  conda-forge
#     libcblas-3.9.0             |37_h0358290_openblas          17 KB  conda-forge
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-15.2.0              |       h767d61c_6         804 KB  conda-forge
#     libgcc-ng-15.2.0           |       h69a702a_6          29 KB  conda-forge
# ...

# %%
# %%bash
# conda list -n test
# Out:
# # packages in environment at /usr/local/envs/test:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# bzip2                     1.0.8                h5eee18b_6
# ca-certificates           2025.9.9             h06a4308_0
# expat                     2.7.1                h6a678d5_0
# ld_impl_linux-64          2.44                 h153f514_2
# libblas                   3.9.0           37_h4a7cf45_openblas    conda-forge
# libcblas                  3.9.0           37_h0358290_openblas    conda-forge
# libffi                    3.4.4                h6a678d5_1
# libgcc                    15.2.0               h767d61c_6    conda-forge
# libgcc-ng                 15.2.0               h69a702a_6    conda-forge
# libgfortran-ng            11.2.0               h00389a5_1
# libgfortran5              11.2.0               h1234567_1
# ...

# %%
# %%bash
# eval "$(conda shell.bash hook)"
# conda activate test
# conda install conda-forge::pandas
# Out:
# ...
# Solving environment: ...working...
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::libgomp==15.2.0=h767d61c_6
#   - conda-forge/linux-64::numpy==2.3.3=py314h5d5eb18_0
#   - defaults/linux-64::_openmp_mutex==5.1=1_gnu
#   - conda-forge/linux-64::libgcc==15.2.0=h767d61c_6
#   - defaults/linux-64::libgfortran-ng==11.2.0=h00389a5_1
#   - defaults/linux-64::libstdcxx-ng==11.2.0=h1234567_1
#   - conda-forge/linux-64::libblas==3.9.0=37_h4a7cf45_openblas
#   - defaults/linux-64::libmpdec==4.0.0=h5eee18b_0
#   - defaults/linux-64::openssl==3.0.18=hd6dcaed_0
#   - conda-forge/linux-64::liblapack==3.9.0=37_h47877c9_openblas
#   - defaults/linux-64::python==3.14.0=h3fc5862_100_cp314
#   - defaults/linux-64::xz==5.6.4=h5eee18b_1
#   - defaults/linux-64::sqlite==3.50.2=hb25bd0a_1
#   - defaults/linux-64::ld_impl_linux-64==2.44=h153f514_2
#   - defaults/linux-64::lz4-c==1.9.4=h6a678d5_1
# ...

# %%
# %%bash
# %%bash
# conda list -n test
# Out:
# # packages in environment at /usr/local/envs/test:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# bzip2                     1.0.8                h5eee18b_6
# ca-certificates           2025.9.9             h06a4308_0
# expat                     2.7.1                h6a678d5_0
# ld_impl_linux-64          2.44                 h153f514_2
# libblas                   3.9.0           37_h4a7cf45_openblas    conda-forge
# libcblas                  3.9.0           37_h0358290_openblas    conda-forge
# libffi                    3.4.4                h6a678d5_1
# libgcc                    15.2.0               h767d61c_6    conda-forge
# libgcc-ng                 15.2.0               h69a702a_6    conda-forge
# libgfortran-ng            11.2.0               h00389a5_1
# libgfortran5              11.2.0               h1234567_1
# ...
